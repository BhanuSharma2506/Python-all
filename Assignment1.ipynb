# %% [markdown]
# Question: What will be the output of the following code?

# %%
x = 5
y = 3.2
z = "Hello"
print(x + y)
print(z + "World")
# Out:
# 8.2
# HelloWorld

# %% [markdown]
# Question: Write a Python function is_even that takes an integer as an argument and returns True if
# the number is even, and False otherwise.

# %%
def is_even(num):
return num % 2 == 0
# Out:
#   File "<ipython-input-9-e3aa8bb6f691>", line 2
#     return num % 2 == 0
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# Question: What will be the result of the following expression?

# %%
result=10%3
print(result)
# Out:
# 1

# %% [markdown]
# What does the expression 7 != 5 evaluate to?

# %%
a=7
b=5
a!=b
# Out:
# True

# %% [markdown]
# What will be the result of the following expression?

# %%
x=True
y=False
print(x and y)
# Out:
# False

# %% [markdown]
# What will be the value of a after the following code is executed?

# %%
a = 5
a += 3
print(a)
# Out:
# 8

# %% [markdown]
# What is the result of the following operation?

# %%
greeting = "Hello, " + "World!"
print(greeting)
# Out:
# Hello, World!

# %% [markdown]
# Question: What will be the result of the following code?

# %%
a='python'*3
print(a)
# Out:
# pythonpythonpython

# %% [markdown]
# Question: What will be the result of converting the string &quot;42&quot; to an integer and adding 8?

# %%
a=int("42")+8
print(a)
# Out:
# 50

# %% [markdown]
# Question: What will be the result of the following code?

# %%
a=17
b=4
a//4
# Out:
# 4
