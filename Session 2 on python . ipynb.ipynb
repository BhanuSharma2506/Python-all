# %%
#identity operator
a=[1,2,3]
b=[1,2,3]
print(a==b)
# Out:
# True

# %%
print(a is b)
# Out:
# False

# %%
print(id(a))
# Out:
# 137952087615296

# %%
print(id(b))
# Out:
# 137952087615488

# %%
a=12
b=12
print(a==b)
print(a is b)
# Out:
# True
# True

# %%
#bitwise operator
a=8
b=14
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 8
# 14
# 6

# %%
1+5/5*6+4-7**2   #arithmetic operator(BODMAS)
(PEMDAS)
>>   PARENTHESES(BRACKET)
>>EXPONENT(**)
>>MULTIPLICATION YA DIVISION
>>ADDITION YA SUBST
# Out:
#   File "<ipython-input-18-b6a2b4bb49e5>", line 3
#     >>   PARENTHESES(BRACKET)
#     ^
# SyntaxError: invalid syntax

# %%
username='bhanu'
m=f'hello {username}'
print(m)
# Out:
# hello bhanu
